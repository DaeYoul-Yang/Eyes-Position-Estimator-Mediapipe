# %% [markdown]
# <a href="https://colab.research.google.com/github/DaeYoul-Yang/Eyes-Position-Estimator-Mediapipe/blob/master/Cproject_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, glob
import scipy
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img
from keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from keras.layers import GlobalAveragePooling2D, Dense
from keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint

# %%
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive
# Out:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 122349 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.4.0-2ubuntu1.2_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.4.0-2ubuntu1.2) ...
# Setting up libarchive-dev:amd64 (3.4.0-2ubuntu1.2) ...
# Processing triggers for man-db (2.9.1-1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 6.6 MB/s eta 0:00:00
# ...
#   Created wheel for libarchive: filename=libarchive-0.4.7-py3-none-any.whl size=31644 sha256=a2fbec4ae03bf56048358105d3b82ec4d2a2272fe1c14a7158d8dce81bb32298
#   Stored in directory: /root/.cache/pip/wheels/c9/a5/cc/cb20f1314d4cdec0001fd72baa1efe93e1542a81bdea2fc639
# Successfully built libarchive
# ...

# %%
# !apt-get -qq install -y graphviz && pip install pydot
import pydot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install keras --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install matplotlib-venn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
from tensorflow.keras.preprocessing.image import img_to_array

# %%
import cv2
import matplotlib.pyplot as plt
image_path = '/content/drive/MyDrive/img_127040601.jpg'
image = cv2.imread(image_path)

plt.imshow(image)
plt.show()

# %%
filepath='content/gdrive/My Drive/'
BASE_PATH = 'data'

full_list = glob.glob(os.path.join(BASE_PATH, 'Full/*.jpg'))
free_list = glob.glob(os.path.join(BASE_PATH, 'Free/*.jpg'))

full_img = img_to_array(load_img(full_list[0]), dtype=np.uint8)
free_img = img_to_array(load_img(free_list[0]), dtype=np.uint8)

plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plt.title(len(full_list))
plt.imshow(full_img)
plt.subplot(1, 2, 2)
plt.title(len(free_list))
plt.imshow(free_img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-bc3bb78bd677> in <cell line: 7>()
#       5 free_list = glob.glob(os.path.join(BASE_PATH, 'Free/*.jpg'))
#       6
# ----> 7 full_img = img_to_array(load_img(full_list[0]), dtype=np.uint8)
#       8 free_img = img_to_array(load_img(free_list[0]), dtype=np.uint8)
#       9
#
# IndexError: list index out of range
